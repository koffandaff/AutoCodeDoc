# %% [markdown]
# # Weather Model Training Tutorial
#
# **Note:** This notebook is intentionally small in scope. It uses reduced parameters, runs on CPU only, and uses DANRA test data. The goal is to walk you through the same steps you'd follow with your own data and real compute, not to suggest a full weather model can be trained in a browser tab.
#
# In production, this notebook runs on a weekly CI schedule against the `main` branch, and the executed notebook artifacts are stored on a `docs-artifacts` branch. Colab and Binder links point to that artifact branch to ensure you always see outputs from a verified run.

# %%
print('Initializing lightweight training job...')
